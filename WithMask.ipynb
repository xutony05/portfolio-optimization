# %%
import numpy as np
import math
import gym
from gym.spaces import Box, Dict, Tuple, Discrete
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sb
from tqdm import tqdm
import random
from collections import namedtuple, deque

# %%
MAX_EPISODES = 10000
N_TRIALS = 50
TEMPERATURE = [10000, 9000, 8000, 7000, 6000, 5000, 4000, 3000, 2000, 1000, 100]

# %%
def state_bounds_gen():
  state_bound_dict={
      "asset1":[-np.finfo(np.float32).max,np.finfo(np.float32).max],
      "asset2":[-np.finfo(np.float32).max,np.finfo(np.float32).max],
      "asset3":[-np.finfo(np.float32).max,np.finfo(np.float32).max],
      "balance":[0,np.finfo(np.float32).max],
      "price1":[-np.finfo(np.float32).max,np.finfo(np.float32).max],
      "price2":[-np.finfo(np.float32).max,np.finfo(np.float32).max],
      "price3":[-np.finfo(np.float32).max,np.finfo(np.float32).max]

  }
  return state_bound_dict

class mytradingenv(gym.Env):
  def __init__(self,*args, **kwargs):
      df = pd.read_csv("stock.csv")
      self.coke = df[df["Symbol"]=="COKE"].tail(20)["Average_Stock_Value_After_Result"].values
      self.msft = df[df["Symbol"]=="MSFT"].tail(20)["Average_Stock_Value_After_Result"].values
      self.tesla = df[df["Symbol"]=="TSLA"].tail(20)["Average_Stock_Value_After_Result"].values
      self.transction_cost = 0.5
      self.tvec=np.arange(20)                              # Length of each episode=20


      state_bounds=state_bounds_gen()
      low,high= map(np.array,zip(*state_bounds.values()))  # Minimun and maximum values for the state variables

      self.action_space = Tuple([Discrete(11),Discrete(11),Discrete(11)])  #Action space consisting of three discrete actions

      self.observation_space=Dict({"action_mask":Tuple([Box(0,1,shape=(11,)),Box(0,1,shape=(11,)),Box(0,1,shape=(11,))]),
                                     "trading_state":Box(low,high,dtype=np.float32)})  # Dictionary space consisting of trading state
                                                                                       # and action mask

  def reset(self):
      self.assets=np.zeros(3,dtype=np.float32)        # Assets owned at the beginning
      self.balance=10000                               # Initial cash balance
      self.t_step=0
      self.prices=[self.coke[0], self.msft[0], self.tesla[0]]  # Sampling marker prices for the assets
      self.state=np.hstack([self.assets, self.balance, self.prices])        # Initial state
      self.total_assets=self.balance                                        # Total portfolio value
      self.update_mask()                                                    # Updating action mask values
      reset_state={
          "action_mask":list(np.float32(self.action_mask)),                 # Initial state
          "trading_state":np.float32(self.state)
      }
      return reset_state

  def step(self,action):
      self.t_step+=1

      for index, a in enumerate (action):
          quant=abs(a-5)
          if a < 5:                                                     # Condition: Asset sale ?
              if 10 * quant * self.transction_cost > self.balance:        # Condition: sale cost > Balance ?
                  quant = np.floor(self.balance / (10 * self.transction_cost))
              self.assets[index] -= 10 * quant                               # Asset update
              self.balance = self.balance + 10 * quant * (self.prices[index] - self.transction_cost) # Balance update
          elif a > 5:
              if 10*quant*(self.transction_cost + self.prices[index])>self.balance:          # Condition: Buy cost > Balance ?
                  quant=np.floor(self.balance/(10*(self.transction_cost + self.prices[index])))
              self.assets[index]+=10*quant                               # Asset update
              self.balance=self.balance-10*quant*(self.prices[index]+self.transction_cost) # Balance update
          else:
              continue

      self.prices=np.array([self.coke[self.t_step], self.msft[self.t_step], self.tesla[self.t_step]]) # New asset prices
      self.state=np.hstack([self.assets,self.balance, self.prices])                                        # New state
      self.total_assets=self.balance+np.dot(self.assets,self.prices)                                       # Total portfolio value
      self.update_mask()                                                                                   # Mask update

      obs={
          "action_mask": list(np.float32(self.action_mask)),
          "trading_state":np.float32(self.state)

      }

      reward=self.total_assets
      done=True if self.t_step==len(self.tvec)-1 else False
      return obs, reward, done, {}

  def update_mask(self):
      self.action_mask=[np.array([1.0]*x.n) for x in self.action_space.spaces]  # Set all masks to 1

      if self.balance<1:                                                        # If balance < 1, set buy masks to zero (C4)
          for jj in range(len(self.action_mask)):
              self.action_mask[jj][6:]=[0.0]*5

      self.action_mask[0][6:]=[0.0]*5 if (self.prices[0]*self.assets[0]/self.total_assets)>1/2 else [1.0]*5  #(C3)
      self.action_mask[1][6:]=[0.0]*5 if (self.prices[1]*self.assets[1]/self.total_assets)>1/2 else [1.0]*5  #(C3)
      self.action_mask[2][6:]=[0.0]*5 if (self.prices[2]*self.assets[2]/self.total_assets)>1/2 else [1.0]*5  #(C3)

      for k in range(3):
          cap=int(min(5,self.assets[k]/10))
          self.action_mask[k][:5]=[0.0]*(5-cap)+[1.0]*cap                                          # (C1)

# %% [markdown]
# # Baseline

# %%
env = mytradingenv()
initial_state = env.reset()
initial_state

# Constants
DISCOUNT_FACTOR = 0.99

num_inputs = 7
num_outputs = env.action_space[0].n

def eval(env, DISCOUNT_FACTOR):
    done = False

    state = env.reset()
    while not done: # steps in epsiode
        action1 = np.random.choice(np.where(state["action_mask"][0]==1)[0])
        action2 = np.random.choice(np.where(state["action_mask"][1]==1)[0])
        action3 = np.random.choice(np.where(state["action_mask"][2]==1)[0])
        action_to_take = [action1, action2, action3]
        new_state, reward, done, _ = env.step(action_to_take) # take action
        state = new_state

    return reward # total reward for the episode

config_baseline = []

for trial in range(1, N_TRIALS+1):
    trial_rewards = []
    t = 0
    for episode in range(1, MAX_EPISODES+1):
        r = eval(env, DISCOUNT_FACTOR)
        trial_rewards.append(r)
    config_baseline.append(trial_rewards)

config_avg_baseline = np.mean(config_baseline, axis=0)

# %%
np.mean(config_avg_baseline)
# Out:
# 36900.65818937248

# %% [markdown]
# # REINFORCE

# %%
class network(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        # fully connected layer
        self.fc1 = nn.Linear(input_dim, hidden_size)
        self.fc2 = nn.Linear(hidden_size, 3*output_dim)

    def forward(self, x): # forward pass
        state = x["trading_state"]
        x = F.relu(self.fc1(state))
        x = self.fc2(x)
        return x

# %%
def update_policy(returns, log_prob_actions_1, log_prob_actions_2, log_prob_actions_3, optimizer):
    returns = returns.detach()
    loss = - (returns * log_prob_actions_1).sum() - (returns * log_prob_actions_2).sum() - (returns * log_prob_actions_3).sum() # loss
    optimizer.zero_grad()
    loss.backward() # back prop
    optimizer.step() # update weights
    return loss.item()

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0)

# %%
# takes rewards and discount_factor
def calculate_returns(rewards, discount_factor):
    returns = []
    R = 0
    # Iterate over rewards in reversed order
    for r in reversed(rewards):
        # Update R using the formula for discounted returns
        R = r + R * discount_factor
        # Insert the calculated return at the beginning of the list
        returns.insert(0, R)
    # Convert the list of returns to a torch tensor
    returns = torch.tensor(returns)
    # Normalize the returns by subtracting the mean and dividing by the standard deviation
    returns = (returns - returns.mean()) / returns.std()
    return returns

# %%
env = mytradingenv()

# hyperparameters
hidden_size = 256
learning_rate = 1e-3

# Constants
DISCOUNT_FACTOR = 0.99

num_inputs = 7
num_outputs = env.action_space[0].n

entropy_term = 0.01

# %%
def train(env, policy, optimizer, discount_factor, temperature):
    policy.train()
    log_prob_actions_1 = []
    log_prob_actions_2 = []
    log_prob_actions_3 = []
    rewards = []
    done = False
    state = env.reset()

    # epsiode not finished and reard threshold has not been reached
    while not done:
        state = {key: torch.tensor(value) for key, value in state.items()}
        mask1 = state["action_mask"][0]
        mask2 = state["action_mask"][1]
        mask3 = state["action_mask"][2]
        action_pred = policy(state) # policy network
        action_pred = action_pred.view(3, 11)
        masked_logits1 = action_pred[0]
        masked_logits2 = action_pred[1]
        masked_logits3 = action_pred[2]
        masked_logits1 = torch.nan_to_num(masked_logits1, nan=0)
        masked_logits2 = torch.nan_to_num(masked_logits2, nan=0)
        masked_logits3 = torch.nan_to_num(masked_logits3, nan=0)
        # convert action proabilities to distribution and sample
        masked_logits1 = F.softmax(masked_logits1 / temperature, dim=0) * mask1
        masked_logits2 = F.softmax(masked_logits2 / temperature, dim=0) * mask2
        masked_logits3 = F.softmax(masked_logits3 / temperature, dim=0) * mask3
        if torch.sum(masked_logits1) == 0:
          masked_logits1[5] = 1
        if torch.sum(masked_logits2) == 0:
          masked_logits2[5] = 1
        if torch.sum(masked_logits3) == 0:
          masked_logits3[5] = 1
        masked_logits1 = masked_logits1 / masked_logits1.sum()
        masked_logits2 = masked_logits2 / masked_logits2.sum()
        masked_logits3 = masked_logits3 / masked_logits3.sum()
        # convert action proabilities to distribution and sample
        dist1 = distributions.Categorical(masked_logits1)
        dist2 = distributions.Categorical(masked_logits2)
        dist3 = distributions.Categorical(masked_logits3)
        action1 = dist1.sample()
        action2 = dist2.sample()
        action3 = dist3.sample()
        action_to_take = [action1, action2, action3]
        # log probability
        log_prob_action_1 = dist1.log_prob(action1)
        log_prob_action_2 = dist2.log_prob(action2)
        log_prob_action_3 = dist3.log_prob(action3)
        # selection action
        state, reward, done, _ = env.step(action_to_take)
        # store proability and reward
        log_prob_actions_1.append(log_prob_action_1)
        log_prob_actions_2.append(log_prob_action_2)
        log_prob_actions_3.append(log_prob_action_3)
        rewards.append(reward)
    log_prob_actions_1 = torch.stack(log_prob_actions_1)
    log_prob_actions_2 = torch.stack(log_prob_actions_2)
    log_prob_actions_3 = torch.stack(log_prob_actions_3)
    returns = calculate_returns(rewards, discount_factor) # discount rewards
    loss = update_policy(returns, log_prob_actions_1, log_prob_actions_2, log_prob_actions_3, optimizer) # update network
    return loss, rewards[-1]

# %%
def eval(env, policy, discount_factor, temperature):
    policy.eval()
    done = False
    state = env.reset()
    rewards = []

    for i in range(100):
      # epsiode not finished and reard threshold has not been reached
      while not done:
          state = {key: torch.tensor(value) for key, value in state.items()}
          mask1 = state["action_mask"][0]
          mask2 = state["action_mask"][1]
          mask3 = state["action_mask"][2]
          action_pred = policy(state) # policy network
          action_pred = action_pred.view(3, 11)
          masked_logits1 = action_pred[0]
          masked_logits2 = action_pred[1]
          masked_logits3 = action_pred[2]
          masked_logits1 = torch.nan_to_num(masked_logits1, nan=0)
          masked_logits2 = torch.nan_to_num(masked_logits2, nan=0)
          masked_logits3 = torch.nan_to_num(masked_logits3, nan=0)
          # convert action proabilities to distribution and sample
          masked_logits1 = F.softmax(masked_logits1 / temperature, dim=0) * mask1
          masked_logits2 = F.softmax(masked_logits2 / temperature, dim=0) * mask2
          masked_logits3 = F.softmax(masked_logits3 / temperature, dim=0) * mask3
          if torch.sum(masked_logits1) == 0:
            masked_logits1[5] = 1
          if torch.sum(masked_logits2) == 0:
            masked_logits2[5] = 1
          if torch.sum(masked_logits3) == 0:
            masked_logits3[5] = 1
          masked_logits1 = masked_logits1 / masked_logits1.sum()
          masked_logits2 = masked_logits2 / masked_logits2.sum()
          masked_logits3 = masked_logits3 / masked_logits3.sum()
          # convert action proabilities to distribution and sample
          dist1 = distributions.Categorical(masked_logits1)
          dist2 = distributions.Categorical(masked_logits2)
          dist3 = distributions.Categorical(masked_logits3)
          action1 = dist1.sample()
          action2 = dist2.sample()
          action3 = dist3.sample()
          action_to_take = [action1, action2, action3]
          # selection action
          state, reward, done, _ = env.step(action_to_take)
      rewards.append(reward)
    return rewards

# %%
config_REINFORCE = [] # decreasing temperature
test_rewards_REINFORCE = []

# %%
for trial in range(1, N_TRIALS+1):
    trial_rewards = []
    policy = network(num_inputs, hidden_size, num_outputs) # linear approximation layer
    policy.apply(init_weights) # apply weights
    optimizer = optim.Adam(policy.parameters(), lr = learning_rate) # optimzer
    for episode in range(1, MAX_EPISODES+1):
        TEMP = TEMPERATURE[episode//1000] # decrease temperature every 100 episodes
        loss, train_reward = train(env, policy, optimizer, DISCOUNT_FACTOR, TEMP)
        trial_rewards.append(train_reward)
        if episode % 50 == 0:
            print(f'Config | Trial: {trial:2} | Episode: {episode:4} | Rewards: {train_reward:5.1f}')
    config_REINFORCE.append(trial_rewards)
    reward = eval(env, policy, DISCOUNT_FACTOR, 50)
    test_rewards_REINFORCE.append(np.mean(reward))
config_avg_REINFORCE = np.mean(config_REINFORCE, axis=0)
# Out:
# C:\Users\17436\AppData\Local\Temp\ipykernel_27320\2456490723.py:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:278.)
#   state = {key: torch.tensor(value) for key, value in state.items()}
# Config | Trial:  1 | Episode:   50 | Rewards: 36124.5
# Config | Trial:  1 | Episode:  100 | Rewards: 35547.9
# Config | Trial:  1 | Episode:  150 | Rewards: 27091.3
# Config | Trial:  1 | Episode:  200 | Rewards: 56430.7
# Config | Trial:  1 | Episode:  250 | Rewards: 63019.7
# Config | Trial:  1 | Episode:  300 | Rewards: 57603.6
# Config | Trial:  1 | Episode:  350 | Rewards: 41893.6
# Config | Trial:  1 | Episode:  400 | Rewards: 50227.5
# Config | Trial:  1 | Episode:  450 | Rewards: 33930.1
# Config | Trial:  3 | Episode: 9600 | Rewards: 30738.2
# Config | Trial:  3 | Episode: 9650 | Rewards: 35065.6
# Config | Trial:  3 | Episode: 9700 | Rewards: 35815.2
# Config | Trial:  3 | Episode: 9750 | Rewards: 29312.0
# Config | Trial:  3 | Episode: 9800 | Rewards: 34886.8
# Config | Trial:  3 | Episode: 9850 | Rewards: 23902.5
# Config | Trial:  3 | Episode: 9900 | Rewards: 22472.7
# Config | Trial:  3 | Episode: 9950 | Rewards: 26538.3
# Config | Trial:  3 | Episode: 10000 | Rewards: 31043.3
# Config | Trial:  4 | Episode:   50 | Rewards: 43059.7
# Config | Trial:  4 | Episode:  100 | Rewards: 20752.1
# Config | Trial:  4 | Episode:  150 | Rewards: 31957.1
# Config | Trial:  4 | Episode:  200 | Rewards: 45522.2
# Config | Trial:  4 | Episode:  250 | Rewards: 28851.7
# Config | Trial:  4 | Episode:  300 | Rewards: 26847.9
# Config | Trial:  4 | Episode:  350 | Rewards: 46637.6
# Config | Trial:  4 | Episode:  400 | Rewards: 40848.8
# Config | Trial:  4 | Episode:  450 | Rewards: 58678.2
# Config | Trial:  4 | Episode:  500 | Rewards: 36211.3
# Config | Trial:  4 | Episode:  550 | Rewards: 31063.6
# Config | Trial:  4 | Episode:  600 | Rewards: 49105.8
# Config | Trial:  4 | Episode:  650 | Rewards: 35920.2
# Config | Trial:  4 | Episode:  700 | Rewards: 52362.4
# Config | Trial:  4 | Episode:  750 | Rewards: 54876.1
# Config | Trial:  4 | Episode:  800 | Rewards: 40191.9
# Config | Trial:  4 | Episode:  850 | Rewards: 19494.5
# Config | Trial:  4 | Episode:  900 | Rewards: 28621.9
# Config | Trial:  4 | Episode:  950 | Rewards: 25139.7
# Config | Trial:  4 | Episode: 1000 | Rewards: 18374.2
# Config | Trial:  4 | Episode: 1050 | Rewards: 38265.1
# Config | Trial:  4 | Episode: 1100 | Rewards: 30349.6
# Config | Trial:  4 | Episode: 1150 | Rewards: 29351.7
# Config | Trial:  4 | Episode: 1200 | Rewards: 53559.9
# Config | Trial:  4 | Episode: 1250 | Rewards: 21134.3
# Config | Trial:  4 | Episode: 1300 | Rewards: 24059.3
# Config | Trial:  4 | Episode: 1350 | Rewards: 40578.5
# Config | Trial:  4 | Episode: 1400 | Rewards: 62022.0
# Config | Trial:  4 | Episode: 1450 | Rewards: 34633.3
# Config | Trial:  4 | Episode: 1500 | Rewards: 33259.6
# Config | Trial:  4 | Episode: 1550 | Rewards: 29339.5
# Config | Trial:  4 | Episode: 1600 | Rewards: 25164.5
# Config | Trial:  4 | Episode: 1650 | Rewards: 30365.1
# Config | Trial:  4 | Episode: 1700 | Rewards: 26071.2
# Config | Trial:  4 | Episode: 1750 | Rewards: 37330.0
# Config | Trial:  4 | Episode: 1800 | Rewards: 47318.9
# Config | Trial:  4 | Episode: 1850 | Rewards: 45351.7
# Config | Trial:  4 | Episode: 1900 | Rewards: 34258.3
# Config | Trial:  4 | Episode: 1950 | Rewards: 35716.8
# Config | Trial:  4 | Episode: 2000 | Rewards: 34315.9
# Config | Trial:  5 | Episode: 9000 | Rewards: 42920.6
# Config | Trial:  5 | Episode: 9050 | Rewards: 33506.2
# Config | Trial:  5 | Episode: 9100 | Rewards: 41332.8
# Config | Trial:  5 | Episode: 9150 | Rewards: 32880.6
# Config | Trial:  5 | Episode: 9200 | Rewards: 45012.6
# Config | Trial:  5 | Episode: 9250 | Rewards: 45987.7
# Config | Trial:  5 | Episode: 9300 | Rewards: 44406.4
# Config | Trial:  5 | Episode: 9350 | Rewards: 46405.5
# Config | Trial:  5 | Episode: 9400 | Rewards: 27324.6
# Config | Trial:  5 | Episode: 9450 | Rewards: 40691.2
# Config | Trial:  5 | Episode: 9500 | Rewards: 38642.2
# Config | Trial:  5 | Episode: 9550 | Rewards: 72204.1
# Config | Trial:  5 | Episode: 9600 | Rewards: 54061.2
# Config | Trial:  5 | Episode: 9650 | Rewards: 37822.3
# Config | Trial:  5 | Episode: 9700 | Rewards: 59573.3
# Config | Trial:  5 | Episode: 9750 | Rewards: 39842.2
# Config | Trial:  5 | Episode: 9800 | Rewards: 43734.0
# Config | Trial:  5 | Episode: 9850 | Rewards: 50350.5
# Config | Trial:  5 | Episode: 9900 | Rewards: 50111.2
# Config | Trial:  5 | Episode: 9950 | Rewards: 36470.4
# Config | Trial:  5 | Episode: 10000 | Rewards: 56414.2

# %%
np.mean(test_rewards_REINFORCE)
# Out:
# 38608.305

# %% [markdown]
# # Actor Critic

# %%
env = mytradingenv()
env_test = mytradingenv()
# define actor critic model
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_action, hidden_size, learning_rate=1e-3):
        super(ActorCritic, self).__init__()

        self.num_action = num_action
        # 2 layers for critic
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        # 2 layers for actor
        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, 3*num_action)

    def forward(self, state, temp): # forward pass
        mask1 = state["action_mask"][0]
        mask2 = state["action_mask"][1]
        mask3 = state["action_mask"][2]
        state = state["trading_state"]

        value = F.relu(self.critic_linear1(state)) # ReLU activation for first layer
        value = self.critic_linear2(value)

        policy_dist = F.relu(self.actor_linear1(state)) # ReLU activation for first layer
        policy_dist = self.actor_linear2(policy_dist)
        policy_dist = policy_dist.view(-1, 3, 11)

        # Apply masks independently to each agent's logits
        masked_logits1 = policy_dist[:, 0, :]
        masked_logits2 = policy_dist[:, 1, :]
        masked_logits3 = policy_dist[:, 2, :]

        masked_logits1 = F.softmax(masked_logits1[0] / temp, dim=0) * mask1
        masked_logits2 = F.softmax(masked_logits2[0] / temp, dim=0) * mask2
        masked_logits3 = F.softmax(masked_logits3[0] / temp, dim=0) * mask3

        masked_logits1 /= masked_logits1.sum()
        masked_logits2 /= masked_logits2.sum()
        masked_logits3 /= masked_logits3.sum()

         # Concatenate masked logits back together
        policy_dist = torch.stack([masked_logits1, masked_logits2, masked_logits3], dim=0)

        return value, policy_dist # critic value and policy distribution

def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0)

# hyperparameters
hidden_size = 256
learning_rate = 1e-3

# Constants
DISCOUNT_FACTOR = 0.99

num_inputs = 7
num_outputs = env.action_space[0].n

entropy_term = 0.01

def train(env, actor_critic, ac_optimizer, DISCOUNT_FACTOR, TEMP, entropy_term):
    log_probs_1 = []
    log_probs_2 = []
    log_probs_3 = []
    values = []
    rewards = []
    done = False

    state = env.reset()
    state = {key: torch.tensor(value) for key, value in state.items()}
    while not done: # steps in epsiode
        value, policy_dist = actor_critic.forward(state, TEMP) # get critic value and policy distribution
        value = value.detach().numpy()[0] # convert to numpy
        dist = policy_dist.detach().numpy() # convert to numpy
        dist = np.nan_to_num(dist, nan=0)

        action1 = np.random.choice(num_outputs, p=np.squeeze(dist[0])) # choose action based on policy distribution
        action2 = np.random.choice(num_outputs, p=np.squeeze(dist[1]))
        action3 = np.random.choice(num_outputs, p=np.squeeze(dist[2]))
        action_to_take = [action1, action2, action3]

        #print(policy_dist)
        log_1 = torch.log(policy_dist[0][action1]) # compute log probability
        log_2 = torch.log(policy_dist[1][action2])
        log_3 = torch.log(policy_dist[2][action3])

        entropy = -np.sum(np.mean(dist[0]) * np.log(dist[0]) + np.mean(dist[1]) * np.log(dist[1]) + np.mean(dist[2]) * np.log(dist[2])) # compute entropy
        new_state, reward, done, _ = env.step(action_to_take) # take action

        rewards.append(reward)
        values.append(value)
        log_probs_1.append(log_1)
        log_probs_2.append(log_2)
        log_probs_3.append(log_3)
        entropy_term += entropy
        new_state = {key: torch.tensor(value) for key, value in state.items()}
        state = new_state

    Qval, _ = actor_critic.forward(new_state, TEMP) # q values for the new state
    Qval = Qval.detach().numpy()[0] # convert to nbumpy

    update_policy(rewards, values, Qval, log_probs_1, log_probs_2, log_probs_3, ac_optimizer, DISCOUNT_FACTOR, entropy_term)

    return rewards[-1] # total reward for the episode

def update_policy(rewards, values, Qval, log_probs_1, log_probs_2, log_probs_3, optimizer, DISCOUNT_FACTOR, entropy_term):
    # compute Q values
    Qvals = np.zeros_like(values)
    for t in reversed(range(len(rewards))): # loop backward through rewards
        Qval = rewards[t] + DISCOUNT_FACTOR * Qval # compute q value
        Qvals[t] = Qval # store q value

    # convert to tensor
    values = torch.FloatTensor(values)
    Qvals = torch.FloatTensor(Qvals)

    log_probs_1 = torch.stack(log_probs_1)
    log_probs_2 = torch.stack(log_probs_2)
    log_probs_3 = torch.stack(log_probs_3)

    # update actor critic
    advantage = Qvals - values
    actor_loss = (-log_probs_1 * advantage).mean() + (-log_probs_2 * advantage).mean() + (-log_probs_3 * advantage).mean()
    critic_loss = 0.5 * advantage.pow(2).mean()
    ac_loss = actor_loss + critic_loss + 0.001 * entropy_term # compute total loss with entropy regularization

    optimizer.zero_grad()
    ac_loss.backward() # backpropagnate the loss
    optimizer.step() # udpate parameters

def eval(env, actor_critic, DISCOUNT_FACTOR, TEMP):
    rewards = []

    for i in range(1, 101):
      done = False
      state = env.reset()
      state = {key: torch.tensor(value) for key, value in state.items()}
      r = []
      while not done: # steps in epsiode
          value, policy_dist = actor_critic.forward(state, TEMP) # get critic value and policy distribution
          value = value.detach().numpy()[0] # convert to numpy
          dist = policy_dist.detach().numpy() # convert to numpy
          # Check if NaN values exist in dist
          has_nan = np.isnan(dist).any(axis=1)
          # Replace NaN with 0 in each array if NaN exists, and normalize
          for i, has_nan_row in enumerate(has_nan):
              if has_nan_row:
                  dist[i] = np.nan_to_num(dist[i], nan=0)
                  row_sum = np.sum(dist[i])
                  if row_sum != 0:
                      dist[i] /= row_sum
                  else:
                      dist[i][5] =1

          action1 = np.random.choice(num_outputs, p=np.squeeze(dist[0])) # choose action based on policy distribution
          action2 = np.random.choice(num_outputs, p=np.squeeze(dist[1]))
          action3 = np.random.choice(num_outputs, p=np.squeeze(dist[2]))
          action_to_take = [action1, action2, action3]

          new_state, reward, done, _ = env.step(action_to_take) # take action

          new_state = {key: torch.tensor(value) for key, value in new_state.items()}
          state = new_state
      rewards.append(reward)
    return rewards # total reward for the episode

config_AC = [] # decreasing temperature

test_rewards_AC = []

for trial in range(1, N_TRIALS+1):
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    actor_critic.apply(init_weights)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)
    trial_rewards = []
    t = 0
    for episode in range(1, MAX_EPISODES+1):
        r = train(env, actor_critic, ac_optimizer, DISCOUNT_FACTOR, TEMPERATURE[t], entropy_term)
        trial_rewards.append(r)
        if episode % 50 == 0:
            print(f'Config | Trial: {trial:2} | Episode: {episode:3} | Rewards: {r:5.1f}')
        if episode % 1000 == 0:
          t += 1
    config_AC.append(trial_rewards)
    actor_critic.eval()
    reward = eval(env, actor_critic, DISCOUNT_FACTOR, 50)
    test_rewards_AC.append(np.mean(reward))

config_avg_AC = np.mean(config_AC, axis=0)
# Out:
# C:\Users\17436\AppData\Local\Temp\ipykernel_27320\1582353556.py:91: RuntimeWarning: divide by zero encountered in log
#   entropy = -np.sum(np.mean(dist[0]) * np.log(dist[0]) + np.mean(dist[1]) * np.log(dist[1]) + np.mean(dist[2]) * np.log(dist[2])) # compute entropy
# C:\Users\17436\AppData\Local\Temp\ipykernel_27320\1582353556.py:100: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   new_state = {key: torch.tensor(value) for key, value in state.items()}
# Config | Trial:  1 | Episode:  50 | Rewards: 36037.4
# Config | Trial:  1 | Episode: 100 | Rewards: 37129.0
# Config | Trial:  1 | Episode: 150 | Rewards: 38244.7
# Config | Trial:  1 | Episode: 200 | Rewards: 40642.3
# Config | Trial:  1 | Episode: 250 | Rewards: 40745.9
# Config | Trial:  1 | Episode: 300 | Rewards: 39438.3
# Config | Trial:  1 | Episode: 350 | Rewards: 38379.8
# Config | Trial:  1 | Episode: 400 | Rewards: 44305.9
# Config | Trial:  1 | Episode: 450 | Rewards: 40562.8
# Config | Trial:  1 | Episode: 500 | Rewards: 40617.4
# Config | Trial:  1 | Episode: 550 | Rewards: 38551.3
# Config | Trial:  1 | Episode: 600 | Rewards: 43074.4
# Config | Trial:  1 | Episode: 650 | Rewards: 41840.8
# Config | Trial:  1 | Episode: 700 | Rewards: 38596.7
# Config | Trial:  1 | Episode: 750 | Rewards: 34817.7
| Rewards: 51349.5
# Config | Trial:  5 | Episode: 2850 | Rewards: 39483.7
# Config | Trial:  5 | Episode: 2900 | Rewards: 40746.8
# Config | Trial:  5 | Episode: 2950 | Rewards: 40676.5
# Config | Trial:  5 | Episode: 3000 | Rewards: 50040.1
# Config | Trial:  5 | Episode: 3050 | Rewards: 40746.8
# Config | Trial:  5 | Episode: 3100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3150 | Rewards: 38551.2
# Config | Trial:  5 | Episode: 3200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3350 | Rewards: 40676.5
# Config | Trial:  5 | Episode: 3400 | Rewards: 51554.1
# Config | Trial:  5 | Episode: 3450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3500 | Rewards: 40676.5
# Config | Trial:  5 | Episode: 3550 | Rewards: 40676.5
# Config | Trial:  5 | Episode: 3600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3650 | Rewards: 40862.5
# Config | Trial:  5 | Episode: 3700 | Rewards: 40676.5
# Config | Trial:  5 | Episode: 3750 | Rewards: 40676.5
# Config | Trial:  5 | Episode: 3800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 3850 | Rewards: 27617.1
# Config | Trial:  5 | Episode: 3900 | Rewards: 50244.7
# Config | Trial:  5 | Episode: 3950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4000 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4050 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4150 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4350 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4400 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4500 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4550 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4650 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4700 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4750 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4850 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4900 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 4950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5000 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5050 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5150 | Rewards: 40689.1
# Config | Trial:  5 | Episode: 5200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5350 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5400 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5500 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5550 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5650 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5700 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5750 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5850 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5900 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 5950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6000 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6050 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6150 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6350 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6400 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6500 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6550 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6650 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6700 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6750 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6850 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6900 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 6950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7000 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7050 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7150 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7350 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7400 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7500 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7550 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7650 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7700 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7750 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7850 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7900 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 7950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8000 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8050 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8150 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8350 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8400 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8500 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8550 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8650 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8700 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8750 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8850 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8900 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 8950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9000 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9050 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9100 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9150 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9200 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9250 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9300 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9350 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9400 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9450 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9500 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9550 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9600 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9650 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9700 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9750 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9800 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9850 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9900 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 9950 | Rewards: 51349.5
# Config | Trial:  5 | Episode: 10000 | Rewards: 51349.5

# %%
np.mean(test_rewards_AC)
# Out:
# 60765.36654016135

# %% [markdown]
# # DQN

# %%
env = mytradingenv()
initial_state = env.reset()

# %%
# Define hyperparameters
state_size = env.observation_space["trading_state"].shape[0]
print(state_size)
action_size = env.action_space[0].n
print(action_size)
# Out:
# 7
# 11

# %%
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 256)  # Increase number of neurons in the first layer
        self.fc2 = nn.Linear(256, 256)         # Add another layer with 128 neurons
        self.fc3 = nn.Linear(256, 128)         # Add another layer with 128 neurons
        self.fc4 = nn.Linear(128, 3*output_size) # Output layer remains the same

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))  # Apply ReLU activation to the output of the third layer
        x = self.fc4(x)
        return x

# %%
class DQNAgent:
    def __init__(self, state_size, action_size, use_cuda=False):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
        self.model.to(self.device)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        mask1 = state["action_mask"][0]
        mask2 = state["action_mask"][1]
        mask3 = state["action_mask"][2]
        if np.random.rand() <= self.epsilon:
            filtered_array_1 = [index for index, value in enumerate(mask1) if value == 1]
            filtered_array_2 = [index for index, value in enumerate(mask2) if value == 1]
            filtered_array_3 = [index for index, value in enumerate(mask3) if value == 1]
            action1 = random.choice(filtered_array_1)
            action2 = random.choice(filtered_array_2)
            action3 = random.choice(filtered_array_3)
            return [action1, action2, action3]
        state = state["trading_state"]
        state = torch.FloatTensor(state).to(self.device)
        q_values = self.model(state)
        action_pred = q_values.view(3, 11).cpu().detach().numpy()
        masked_logits1 = action_pred[0] * mask1
        masked_logits2 = action_pred[1] * mask2
        masked_logits3 = action_pred[2] * mask3
        masked_logits1 = [0.001 if x < 0 else x for x in masked_logits1]
        masked_logits2 = [0.001 if x < 0 else x for x in masked_logits2]
        masked_logits3 = [0.001 if x < 0 else x for x in masked_logits3]
        action1 = np.argmax(masked_logits1)
        action2 = np.argmax(masked_logits2)
        action3 = np.argmax(masked_logits3)
        return [action1, action2, action3]

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        states, targets = [], []
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state).to(self.device)
            next_state = torch.FloatTensor(next_state).to(self.device)
            q_values = self.model(state)
            target = q_values.clone().detach()
            if done:
                target[action] = reward
            else:
                next_q_values = self.model(next_state)
                target[action] = reward + self.gamma * torch.max(next_q_values).item()
            states.append(state)
            targets.append(target)
        states = torch.stack(states)
        targets = torch.stack(targets)
        self.optimizer.zero_grad()
        loss = F.mse_loss(self.model(states), targets)
        loss.backward()
        self.optimizer.step()

    def decay_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay


# Training parameters
batch_size = 32
scores_over_trials = []

# Training loop
for trial in range(1,N_TRIALS+1):
    agent = DQNAgent(state_size, action_size, use_cuda=True)
    print("Trials number: ", N_TRIALS)
    trial_scores = []
    for episode in tqdm(range(1, MAX_EPISODES + 1), desc='Episodes', leave=False):
        state = env.reset()
        total_reward = 0
        done = False
        steps = 0
        while not done:
            #print(agent.epsilon)
            steps = steps + 1
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            next_state = next_state
            total_reward = reward
            agent.remember(state["trading_state"], action, reward, next_state["trading_state"], done)
            state = next_state
            agent.replay(batch_size)
            if steps >= 500:
                done = True
        trial_scores.append(total_reward)
        agent.decay_epsilon()
    scores_over_trials.append(trial_scores)
# Out:
# Trials number:  2
# Trials number:  2

# %%
config_avg_DQN = np.mean(scores_over_trials, axis=0)
np.mean(config_avg_DQN[-100:])
# Out:
# 30326.181193270593

# %% [markdown]
# # Graph

# %%
window_size = 10
weights = np.ones(window_size) / window_size
baseline_smoothed = np.convolve(config_avg_baseline, weights, mode='valid')
REINFORCE_smoothed = np.convolve(config_avg_REINFORCE, weights, mode='valid')
AC_smoothed = np.convolve(config_avg_AC, weights, mode='valid')
DQN_smoothed = np.convolve(config_avg_DQN, weights, mode='valid')
plt.figure(figsize=(12,8))
plt.plot(baseline_smoothed, label='Baseline')
plt.plot(REINFORCE_smoothed, label='REINFORCE')
plt.plot(AC_smoothed, label='Actor-Critic')
plt.plot(DQN_smoothed, label='DQN')
plt.xlabel('Episode', fontsize=20)
plt.ylabel('Reward', fontsize=20)
plt.legend(loc='lower right')
plt.grid()
